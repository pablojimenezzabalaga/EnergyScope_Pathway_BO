# %% [markdown]
# <div align="center"><h1><b><font color=>
#   End Use Demand projections by sector and type of usage (2020-2050)
# </b><div>
#
# <div align="center"><h2><b>
#   Calculation based of End Use Demand characterization and Growth trends
# </b></div>
#
# ---
#
# <div align="center"><h3>
#   <b> Developers:</b> Pablo Jimenez Zabalaga, Carlos Fernandez Vazquez
# </div>
#
# ---

# %% [markdown]
# # Growth expectations (BAU trends)

# %% [markdown]
# <div align="justify">
#
# The main assumption considered for projecting demands into the future under BAU conditions is that in Bolivia, energy consumption is heavily linked to population and economic values due to it being a developing country which growth hasn't reach a plateau.
#
# <div align="justify">
#
# Trends considered for this pourpose are population growth, yearly index of volume of sales and yearly mining exports

# %% [markdown]
# ## Population growth expectations

# %% [markdown]
# The input data for the Bolivian expected growth has been directly taken from the National Insitute of Statistics (INE) of Bolivia which has made projections until 2050 following an stable growth. Original data should be found at these sources:
#   <a href='https://www.ine.gob.bo/index.php/censos-y-proyecciones-de-poblacion-sociales/'>www.ine.gob.bo</a> or <a href='https://nube.ine.gob.bo/index.php/s/fyeHKHO9Zaeep2y/download'> direct_download_link</a>

# %%
# Import libraries
from google.colab import files
import pandas as pd

# %%
# # Option1: Upload manually the Excel file (available in the same folder of this notebook)
# input_file = files.upload()
# # Obtain the name of the file
# file_name = list(input_file.keys())[0]
# # Read the Excel file into a Pandas DataFrame
# df_population = pd.read_excel(file_name, header=0, engine='openpyxl')
# #df

# %%
# Option2: Import the Google Drive Excel file
google_drive_url = 'https://docs.google.com/spreadsheets/d/1-SlyGkHA7MlvGr0LI5y6QGOx65d7fmUt/edit?usp=drive_link&ouid=115521570694102221364&rtpof=true&sd=true'
# Find the index of '/edit'
edit_index = google_drive_url.find('/edit')
# Remove all text after '/edit' (including '/edit')
google_drive_url = google_drive_url[:edit_index]
# Append '/export' to the cleaned URL
google_drive_url = google_drive_url + '/export'
# Read the Excel file into a Pandas DataFrame
df_population = pd.read_excel(google_drive_url, header=0, engine='openpyxl')
df_population
# Out:
#     Year  Population
# 0   2020    11677406
# 1   2021    11841955
# 2   2022    12006031
# 3   2023    12169501
# 4   2024    12332252
# 5   2025    12494181
# 6   2026    12655174
# 7   2027    12815140
# 8   2028    12973939
# 9   2029    13131492
# 10  2030    13287672
# 11  2031    13442367
# 12  2032    13595512
# 13  2033    13746998
# 14  2034    13896755
# 15  2035    14044703
# 16  2036    14190792
# 17  2037    14334944
# 18  2038    14477103
# 19  2039    14617203
# 20  2040    14755212
# 21  2041    14891077
# 22  2042    15024732
# 23  2043    15156151
# 24  2044    15285287
# 25  2045    15412105
# 26  2046    15536564
# 27  2047    15658626
# 28  2048    15778250
# 29  2049    15895385
# 30  2050    16010008

# %% [markdown]
# ## Mining sector growth expectations

# %% [markdown]
# The input data for the Bolivian mining sector has been taken from the National Insitute of Statistics (INE) of Bolivia which has the total metric tons exported each year for the period 1990-2020. Exports registered consider the most exploited minerals in Bolivia (Sn, Cu, Pb and Zn). Original data should be found at these sources:
#   <a href='https://www.ine.gob.bo/index.php/estadisticas-economicas/hidrocarburos-mineria/mineria-cuadros-estadisticos/'>www.ine.gob.bo</a> or <a href='https://nube.ine.gob.bo/index.php/s/f8Iw1MPCtTcpFT1/download'> direct_download_link</a>

# %%
# # Option1: Upload manually the Excel file (available in the same folder of this notebook)
# input_file = files.upload()
# # Obtain the name of the file
# file_name = list(input_file.keys())[0]
# # Read the Excel file into a Pandas DataFrame
# df_historic_mining = pd.read_excel(file_name, header=0, engine='openpyxl')
# #df

# %%
# Option2: Import the Google Drive Excel file
google_drive_url = 'https://docs.google.com/spreadsheets/d/12MgHbauiUNRvvnQqa2z7tjTqyLfIJ1a1/edit?usp=drive_link&ouid=115521570694102221364&rtpof=true&sd=true'
# Find the index of '/edit'
edit_index = google_drive_url.find('/edit')
# Remove all text after '/edit' (including '/edit')
google_drive_url = google_drive_url[:edit_index]
# Append '/export' to the cleaned URL
google_drive_url = google_drive_url + '/export'
# Read the Excel file into a Pandas DataFrame
df_historic_mining = pd.read_excel(google_drive_url, header=0, engine='openpyxl')
df_historic_mining
# Out:
#     Year       Tin Ore    Copper Ore       Lead Ore       Zinc Ore
# 0   1990  17248.884000    156.565000   19913.128000  103849.117000
# 1   1991  16829.729000     29.578000   20809.756000  129777.505000
# 2   1992  16516.320000    100.929000   20010.101000  143935.605000
# 3   1993  18634.196000     93.760000   21220.181000  122637.607000
# 4   1994  16026.585000     79.247000   19678.358000  100741.698000
# 5   1995  14419.019000    127.127000   20387.262000  146130.747000
# 6   1996  14801.856000     92.350000   16537.754750  147091.799000
# 7   1997  12897.991000    181.874000   18607.928000  154490.682000
# 8   1998  11308.059000     47.781000   13847.524000  152109.973000
# 9   1999  12416.594000    249.751000   10152.865468  146144.094610
# 10  2000  12502.661300    109.653000    9522.997382  149134.314025
# 11  2001  12039.230780     18.318290    9090.416110  141982.500070
# 12  2002  13210.449460    119.629000    9268.186670  141708.116848
# 13  2003  16386.057843    344.346810    9353.117275  145489.630103
# 14  2004  18114.576789    576.373970   10252.410045  147430.008180
# 15  2005  18639.496860     34.744800   11231.421495  159501.698930
# 16  2006  17669.434300    218.041280   11954.881500  172747.046730
# 17  2007  15972.090500    606.223460   22797.525410  214053.296490
# 18  2008  17311.038372    730.890780   81553.231482  383617.676890
# 19  2009  19574.839230    881.709217   84537.577220  430879.296318
# 20  2010  20070.633970   2062.897980   72803.318337  411408.543201
# 21  2011  20372.578050   4176.480382  100051.088051  427128.502820
# 22  2012  19701.526604   8653.294302   81095.056484  389911.033514
# 23  2013  19282.118760   7548.839837   82135.559593  407331.874540
# 24  2014  19799.395460  10795.326663   76005.852770  445722.948115
# 25  2015  20139.024160   9478.805507   75272.702580  442154.122477
# 26  2016  17805.295940   8459.873304   89510.019162  486954.995310
# 27  2017  18330.595700   7128.787892  111566.076971  503675.776658
# 28  2018  17250.598550   5215.638947  112047.203262  519629.843027
# 29  2019  17122.376360   4478.213710   88341.694532  529114.638535
# 30  2020  14709.348450   2822.376550   64619.225143  359694.704679
# 31  2021  19668.691140   3309.911420   93246.381484  499536.460105
# 32  2022  17556.664460   3608.185150   90115.393534  518480.446194
# 33  2023  15224.868370   3234.270750   86265.950650  409902.982413

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Option 1: this function is used to create a linear trend based on the latest years (15) with data available
#This trend is later used to project the exports per mineral in the future
def linear_projection(df, mineral_name, target_year):
    # Select the columns for the specified mineral and the year column
    data = df[['Year', mineral_name]]

    # Filter data for the last XYZ years
    last_years = data.tail(20)

    # Prepare the data for linear regression
    X = last_years[['Year']]
    y = last_years[mineral_name]

    # Create and fit the linear regression model
    model = LinearRegression()
    model.fit(X, y)

    # Make projections until the target year
    projections = pd.DataFrame({'Year': range(2020, target_year + 1)})
    projections[mineral_name] = model.predict(projections[['Year']])

    return projections

# %%
# Example usage:
# Assuming df is your DataFrame containing the data
# mineral_name is one of 'Sn', 'Cu', 'Pb', or 'Zn'
# target_year is the year until which you want to make projections
df = df_historic_mining
mineral_name = 'Tin Ore'  # Example mineral
target_year = 2050  # Example target year

projection_df = linear_projection(df, mineral_name, target_year)
print(projection_df)
# Out:
#     Year       Tin Ore
# 0   2020  17698.106628
# 1   2021  17618.467710
# 2   2022  17538.828791
# 3   2023  17459.189872
# 4   2024  17379.550953
# 5   2025  17299.912034
# 6   2026  17220.273115
# 7   2027  17140.634196
# 8   2028  17060.995277
# 9   2029  16981.356358
# 10  2030  16901.717439
# 11  2031  16822.078521
# 12  2032  16742.439602
# 13  2033  16662.800683
# 14  2034  16583.161764
# 15  2035  16503.522845
# 16  2036  16423.883926
# 17  2037  16344.245007
# 18  2038  16264.606088
# 19  2039  16184.967169
# 20  2040  16105.328250
# 21  2041  16025.689332
# 22  2042  15946.050413
# 23  2043  15866.411494
# 24  2044  15786.772575
# 25  2045  15707.133656
# 26  2046  15627.494737
# 27  2047  15547.855818
# 28  2048  15468.216899
# 29  2049  15388.577980
# 30  2050  15308.939061

# %%
df_mining = pd.DataFrame({'Year': range(2020, 2050+1)})
minerals_list = ['Tin Ore', 'Copper Ore', 'Lead Ore', 'Zinc Ore']
for mineral in minerals_list :
  df_mining[mineral] = linear_projection(df_historic_mining, mineral, 2050)[mineral]
df_mining
# Out:
#     Year       Tin Ore    Copper Ore       Lead Ore       Zinc Ore
# 0   2020  17698.106628   5810.227798   97026.997708  497648.285559
# 1   2021  17618.467710   6057.794490  100835.746819  513756.668760
# 2   2022  17538.828791   6305.361183  104644.495930  529865.051960
# 3   2023  17459.189872   6552.927876  108453.245041  545973.435160
# 4   2024  17379.550953   6800.494568  112261.994152  562081.818361
# 5   2025  17299.912034   7048.061261  116070.743264  578190.201561
# 6   2026  17220.273115   7295.627954  119879.492375  594298.584762
# 7   2027  17140.634196   7543.194646  123688.241486  610406.967962
# 8   2028  17060.995277   7790.761339  127496.990597  626515.351163
# 9   2029  16981.356358   8038.328032  131305.739708  642623.734363
# 10  2030  16901.717439   8285.894724  135114.488819  658732.117564
# 11  2031  16822.078521   8533.461417  138923.237930  674840.500764
# 12  2032  16742.439602   8781.028110  142731.987042  690948.883964
# 13  2033  16662.800683   9028.594803  146540.736153  707057.267165
# 14  2034  16583.161764   9276.161495  150349.485264  723165.650365
# 15  2035  16503.522845   9523.728188  154158.234375  739274.033566
# 16  2036  16423.883926   9771.294881  157966.983486  755382.416766
# 17  2037  16344.245007  10018.861573  161775.732597  771490.799967
# 18  2038  16264.606088  10266.428266  165584.481709  787599.183167
# 19  2039  16184.967169  10513.994959  169393.230820  803707.566367
# 20  2040  16105.328250  10761.561651  173201.979931  819815.949568
# 21  2041  16025.689332  11009.128344  177010.729042  835924.332768
# 22  2042  15946.050413  11256.695037  180819.478153  852032.715969
# 23  2043  15866.411494  11504.261730  184628.227264  868141.099169
# 24  2044  15786.772575  11751.828422  188436.976375  884249.482370
# 25  2045  15707.133656  11999.395115  192245.725487  900357.865570
# 26  2046  15627.494737  12246.961808  196054.474598  916466.248771
# 27  2047  15547.855818  12494.528500  199863.223709  932574.631971
# 28  2048  15468.216899  12742.095193  203671.972820  948683.015171
# 29  2049  15388.577980  12989.661886  207480.721931  964791.398372
# 30  2050  15308.939061  13237.228578  211289.471042  980899.781572

# %% [markdown]
# ## Industry sector growth expectations

# %% [markdown]
# The input data for the Bolivian mining sector has been taken from the National Insitute of Statistics (INE) of Bolivia, which has the anual index of volume of sales compared to values in 1990 for the period 1990-2019.
# This values represent the aggregated sales from the industrial manufacture sector and provide a rough understanding of the growth trend for the future. Original data should be found at these sources:
#   <a href='https://www.ine.gob.bo/index.php/estadisticas-economicas/industria-manufacturera-y-comercio/estadisticas-coyunturales-cuadros-estadisticos/'>www.ine.gob.bo</a> or <a href='https://nube.ine.gob.bo/index.php/s/e4KGjnr2j1LPdi0/download'> direct_download_link</a>

# %%
# # Option1: Upload manually the Excel file (available in the same folder of this notebook)
# input_file = files.upload()
# # Obtain the name of the file
# file_name = list(input_file.keys())[0]
# # Read the Excel file into a Pandas DataFrame
# df_historic_manufacture = pd.read_excel(file_name, header=0, engine='openpyxl')
# #df

# %%
# Option2: Import the Google Drive Excel file
google_drive_url = 'https://docs.google.com/spreadsheets/d/1U3iOSXakIp8-xR3TURzlccOjcfLMbouq/edit?usp=drive_link&ouid=115521570694102221364&rtpof=true&sd=true'
# Find the index of '/edit'
edit_index = google_drive_url.find('/edit')
# Remove all text after '/edit' (including '/edit')
google_drive_url = google_drive_url[:edit_index]
# Append '/export' to the cleaned URL
google_drive_url = google_drive_url + '/export'
# Read the Excel file into a Pandas DataFrame
df_historic_manufacture = pd.read_excel(google_drive_url, header=0, engine='openpyxl')
df_historic_manufacture
# Out:
#     Year  Volume of Sales Index
# 0   1990              99.852041
# 1   1991             106.228834
# 2   1992             108.255589
# 3   1993             112.582832
# 4   1994             121.775579
# 5   1995             130.757458
# 6   1996             136.320190
# 7   1997             141.382428
# 8   1998             153.027874
# 9   1999             157.862102
# 10  2000             153.268504
# 11  2001             153.174429
# 12  2002             153.174986
# 13  2003             153.786458
# 14  2004             162.442246
# 15  2005             164.664589
# 16  2006             177.471188
# 17  2007             187.981129
# 18  2008             197.819566
# 19  2009             207.162353
# 20  2010             226.703147
# 21  2011             233.057345
# 22  2012             245.662052
# 23  2013             262.544638
# 24  2014             266.227068
# 25  2015             269.774615
# 26  2016             279.318075
# 27  2017             264.137000
# 28  2018             263.831302
# 29  2019             264.076351

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Option 1: this function is used to create a linear trend based on the latest years (20) with data available
#This trend is later used to project the expected sales index in the future

def linear_projection(df, sales_index, target_year):
    # Select the columns for the specified mineral and the year column
    data = df[['Year', sales_index]]

    # Filter data for the last XYZ years
    last_years = data.tail(30)

    # Prepare the data for linear regression
    x = last_years[['Year']]
    y = last_years[sales_index]

    # Create and fit the linear regression model
    model = LinearRegression()
    model.fit(x, y)

    # Make projections until the target year
    projections = pd.DataFrame({'Year': range(2020, target_year + 1)})
    projections[sales_index] = model.predict(projections[['Year']])

    return projections

# %%
df = df_historic_manufacture
sales_index = 'Volume of Sales Index'
target_year = 2050

df_industry = linear_projection(df, sales_index, target_year)
print(df_industry)
# Out:
#     Year  Volume of Sales Index
# 0   2020             285.089349
# 1   2021             291.537432
# 2   2022             297.985515
# 3   2023             304.433598
# 4   2024             310.881681
# 5   2025             317.329763
# 6   2026             323.777846
# 7   2027             330.225929
# 8   2028             336.674012
# 9   2029             343.122095
# 10  2030             349.570178
# 11  2031             356.018260
# 12  2032             362.466343
# 13  2033             368.914426
# 14  2034             375.362509
# 15  2035             381.810592
# 16  2036             388.258675
# 17  2037             394.706757
# 18  2038             401.154840
# 19  2039             407.602923
# 20  2040             414.051006
# 21  2041             420.499089
# 22  2042             426.947171
# 23  2043             433.395254
# 24  2044             439.843337
# 25  2045             446.291420
# 26  2046             452.739503
# 27  2047             459.187586
# 28  2048             465.635668
# 29  2049             472.083751
# 30  2050             478.531834

# %% [markdown]
# # Total EndUseDemand per type of usage

# %%
# Import libraries
from google.colab import files
import pandas as pd
#Import the Google Drive Excel file
google_drive_url = 'https://docs.google.com/spreadsheets/d/1sYqPcTcZpzuHsWliGDkYSn1ffy-YEqGG/edit?usp=drive_link&ouid=115521570694102221364&rtpof=true&sd=true'
# Find the index of '/edit'
edit_index = google_drive_url.find('/edit')
# Remove all text after '/edit' (including '/edit')
google_drive_url = google_drive_url[:edit_index]
# Append '/export' to the cleaned URL
google_drive_url = google_drive_url + '/export'
# Read the Excel file into a Pandas DataFrame
df_EUD = pd.read_excel(google_drive_url, header=0, engine='openpyxl')
print(df_EUD.to_string(index=True))
# Out:
#               Sector          Subsector                Class      Type of usage           Technology           EL           FG          LPG           WD  RES_SOLAR           DS           GS          LFO  Efficiency  Energy intensities              EI units            EUD                          EUD units
# 0        Residential        Residential          Residential      Water Heating            EL Shower  1126.007283          NaN          NaN          NaN        NaN          NaN          NaN          NaN    1.000000        4.342380e-04         GWh/household    1126.007283                       GWh low_temp
# 1        Residential        Residential          Residential      Water Heating            FG Boiler          NaN    32.385179          NaN          NaN        NaN          NaN          NaN          NaN    0.891518        1.113431e-05         GWh/household      28.871982                       GWh low_temp
# 2        Residential        Residential          Residential      Water Heating        Solar Thermal          NaN          NaN          NaN          NaN   11.76003          NaN          NaN          NaN    1.000000        4.535185e-06         GWh/household      11.760030                       GWh low_temp
# 3        Residential        Residential          Residential            Cooking             FG Stove          NaN  1879.671051          NaN          NaN        NaN          NaN          NaN          NaN    0.475000        8.468264e-04         GWh/household     892.843749                        GWh cooking
# 4        Residential        Residential          Residential            Cooking             WD Stove          NaN          NaN          NaN   783.969049        NaN          NaN          NaN          NaN    0.160000        3.407941e-04         GWh/household     125.435048                        GWh cooking
# 5        Residential        Residential          Residential            Cooking            LPG Stove          NaN          NaN  5777.634186          NaN        NaN          NaN          NaN          NaN    0.641331        1.762728e-03         GWh/household    3705.374877                        GWh cooking
# 6        Residential        Residential          Residential            Cooking            LFO Stove          NaN          NaN          NaN          NaN        NaN          NaN          NaN    34.914688    0.494000        6.435767e-02         GWh/household      17.247856                        GWh cooking
# 7        Residential        Residential          Residential            Cooking             EL Stove     2.646743          NaN          NaN          NaN        NaN          NaN          NaN          NaN    1.000000        5.728880e-04         GWh/household       2.646743                        GWh cooking
# 8        Residential        Residential          Residential  Food Preservation      EL Refrigerator   954.635411          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.358127        1.641537e-04         GWh/household     341.880450              GWh food preservation
# 9        Residential        Residential          Residential      Space Heating            EL Heater    21.246432          NaN          NaN          NaN        NaN          NaN          NaN          NaN    1.000000        1.447576e-04         GWh/household      21.246432                  GWh space heating
# 10       Residential        Residential          Residential      Space Cooling                EL AC   311.594516          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.314300        1.417738e-04         GWh/household      97.934156                  GWh space cooling
# 11       Residential        Residential          Residential           Lighting             LED_bulb    30.031021          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.340000        2.807053e-06         GWh/household      10.210547                       GWh lighting
# 12       Residential        Residential          Residential           Lighting    Conventional_bulb   369.968979          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.102500        1.042535e-05         GWh/household      37.921820                       GWh lighting
# 13       Residential        Residential          Residential   Other Appliances        EL appliances   819.071520          NaN          NaN          NaN        NaN          NaN          NaN          NaN    1.000000        2.251767e-04         GWh/household     819.071520                    GWh electricity
# 14         Transport         Passengers           Passengers               Road               FG Car          NaN  1078.142613          NaN          NaN        NaN          NaN          NaN          NaN    0.617935        1.473364e-04  Mkm-passenger/person    1744.751420                      Mkm-passenger
# 15         Transport         Passengers           Passengers               Road               DS Car          NaN          NaN          NaN          NaN        NaN  3501.991131          NaN          NaN    0.718476        4.116037e-04  Mkm-passenger/person    4874.192322                      Mkm-passenger
# 16         Transport         Passengers           Passengers               Road               GS Car          NaN          NaN          NaN          NaN        NaN          NaN  4740.809883          NaN    0.308069        1.299515e-03  Mkm-passenger/person   15388.795306                      Mkm-passenger
# 17         Transport         Passengers           Passengers               Road               EL Car    21.958298          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.160998        1.151743e-05  Mkm-passenger/person     136.388864                      Mkm-passenger
# 18         Transport         Passengers           Passengers               Road               FG Bus          NaN  4314.767814          NaN          NaN        NaN          NaN          NaN          NaN    0.174988        2.082217e-03  Mkm-passenger/person   24657.521093                      Mkm-passenger
# 19         Transport         Passengers           Passengers               Road               DS Bus          NaN          NaN          NaN          NaN        NaN  7975.667920          NaN          NaN    0.115784        5.816947e-03  Mkm-passenger/person   68884.024735                      Mkm-passenger
# 20         Transport         Passengers           Passengers               Road               GS Bus          NaN          NaN          NaN          NaN        NaN          NaN  7816.551291          NaN    0.035941        1.836526e-02  Mkm-passenger/person  217480.576591                      Mkm-passenger
# 21         Transport         Passengers           Passengers               Road      FG Pickup truck          NaN   296.268274          NaN          NaN        NaN          NaN          NaN          NaN    2.340662        1.068865e-05  Mkm-passenger/person     126.574559                      Mkm-passenger
# 22         Transport         Passengers           Passengers               Road      DS Pickup truck          NaN          NaN          NaN          NaN        NaN   717.981784          NaN          NaN    2.030476        2.986016e-05  Mkm-passenger/person     353.602661                      Mkm-passenger
# 23         Transport         Passengers           Passengers               Road      GS Pickup truck          NaN          NaN          NaN          NaN        NaN          NaN   756.637886          NaN    0.677752        9.427447e-05  Mkm-passenger/person    1116.393980                      Mkm-passenger
# 24         Transport         Passengers           Passengers               Road               FG SUV          NaN   433.650111          NaN          NaN        NaN          NaN          NaN          NaN    0.969034        3.779001e-05  Mkm-passenger/person     447.507580                      Mkm-passenger
# 25         Transport         Passengers           Passengers               Road               DS SUV          NaN          NaN          NaN          NaN        NaN  2323.651573          NaN          NaN    1.858667        1.055714e-04  Mkm-passenger/person    1250.171219                      Mkm-passenger
# 26         Transport         Passengers           Passengers               Road               GS SUV          NaN          NaN          NaN          NaN        NaN          NaN  1999.579064          NaN    0.506602        3.333098e-04  Mkm-passenger/person    3947.039370                      Mkm-passenger
# 27         Transport         Passengers           Passengers               Road        FG Motorcycle          NaN    77.570683          NaN          NaN        NaN          NaN          NaN          NaN    0.206446        3.172977e-05  Mkm-passenger/person     375.742490                      Mkm-passenger
# 28         Transport         Passengers           Passengers               Road        DS Motorcycle          NaN          NaN          NaN          NaN        NaN   712.694814          NaN          NaN    0.678960        8.864128e-05  Mkm-passenger/person    1049.686010                      Mkm-passenger
# 29         Transport         Passengers           Passengers               Road        GS Motorcycle          NaN          NaN          NaN          NaN        NaN          NaN  1286.411260          NaN    0.388167        2.798582e-04  Mkm-passenger/person    3314.067662                      Mkm-passenger
# 30         Transport         Passengers           Passengers               Rail           EL Tramway    24.856196          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.070382        2.982272e-05  Mkm-passenger/person     353.159354                      Mkm-passenger
# 31         Transport            Freight              Freight               Road             FG Truck          NaN   505.594918          NaN          NaN        NaN          NaN          NaN          NaN    0.524964        8.132986e-05        Mkm-ton/person     963.104535                            Mkm-ton
# 32         Transport            Freight              Freight               Road             DS Truck          NaN          NaN          NaN          NaN        NaN  1826.781975          NaN          NaN    0.678960        2.272056e-04        Mkm-ton/person    2690.559053                            Mkm-ton
# 33         Transport            Freight              Freight               Road             GS Truck          NaN          NaN          NaN          NaN        NaN          NaN  1773.232997          NaN    0.208748        7.173335e-04        Mkm-ton/person    8494.630453                            Mkm-ton
# 34         Transport            Freight              Freight               Road               FG Van          NaN    32.852272          NaN          NaN        NaN          NaN          NaN          NaN    4.033141        6.878577e-07        Mkm-ton/person       8.145580                            Mkm-ton
# 35         Transport            Freight              Freight               Road               DS Van          NaN          NaN          NaN          NaN        NaN    77.318198          NaN          NaN    3.397744        1.921621e-06        Mkm-ton/person      22.755748                            Mkm-ton
# 36         Transport            Freight              Freight               Road               GS Van          NaN          NaN          NaN          NaN        NaN          NaN   162.435048          NaN    2.260928        6.066940e-06        Mkm-ton/person      71.844426                            Mkm-ton
# 37         Transport            Freight              Freight               Road  DS Cargo motorcycle          NaN          NaN          NaN          NaN        NaN     0.127986          NaN          NaN    6.848640        1.578105e-09        Mkm-ton/person       0.018688                            Mkm-ton
# 38         Transport            Freight              Freight               Road  GS Cargo motorcycle          NaN          NaN          NaN          NaN        NaN          NaN     0.041054          NaN    0.776334        4.465593e-09        Mkm-ton/person       0.052881                            Mkm-ton
# 39         Transport            Freight              Freight               Rail             DS Train          NaN          NaN          NaN          NaN        NaN    58.788573          NaN          NaN    0.073195        6.782519e-05        Mkm-ton/person     803.182891                            Mkm-ton
# 40         Transport            Freight              Freight              Water              DS Boat          NaN          NaN          NaN          NaN        NaN     6.455754          NaN          NaN    0.117408        4.643297e-06        Mkm-ton/person      54.985714                            Mkm-ton
# 41         Transport            Freight              Freight                Air         LFO aircraft          NaN          NaN          NaN          NaN        NaN          NaN          NaN  1024.038006    0.480000        1.801571e-04        Mkm-ton/person    2133.412513                            Mkm-ton
# 42   Public Lighting    Public Lighting      Public Lighting           Lighting   Conventional_light   528.125000          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.102500        1.488203e-05            GWh/person      54.132812                GWh public lighting
# 43        Commercial         Commercial           Commercial           Lighting             LED_bulb    18.802592          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.340000        5.398502e-07            GWh/person       6.392881                       GWh lighting
# 44        Commercial         Commercial           Commercial           Lighting    Conventional_bulb   231.639665          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.102500        2.004995e-06            GWh/person      23.743066                       GWh lighting
# 45        Commercial         Commercial           Commercial            Cooking             FG Stove          NaN   487.756587          NaN          NaN        NaN          NaN          NaN          NaN    0.475000        1.956471e-05            GWh/person     231.684379                        GWh cooking
# 46        Commercial         Commercial           Commercial            Cooking            LPG Stove          NaN          NaN    25.379377          NaN        NaN          NaN          NaN          NaN    0.641331        1.374484e-06            GWh/person      16.276577                        GWh cooking
# 47        Commercial         Commercial           Commercial            Cooking             EL Stove    56.213219          NaN          NaN          NaN        NaN          NaN          NaN          NaN    1.000000        4.746954e-06            GWh/person      56.213219                        GWh cooking
# 48        Commercial         Commercial           Commercial      Water heating            FG Boiler          NaN   119.882441          NaN          NaN        NaN          NaN          NaN          NaN    0.891518        9.025317e-06            GWh/person     106.877396                       GWh low_temp
# 49        Commercial         Commercial           Commercial      Water heating            EL Shower    30.536027          NaN          NaN          NaN        NaN          NaN          NaN          NaN    1.000000        2.578631e-06            GWh/person      30.536027                       GWh low_temp
# 50        Commercial         Commercial           Commercial          Machinery    DS Comm Machinery          NaN          NaN          NaN          NaN        NaN   155.403234          NaN          NaN    0.376393        4.939441e-06            GWh/person      58.492635   GWh commercial mechanical energy
# 51        Commercial         Commercial           Commercial          Machinery    EL Comm Machinery    22.435528          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.825000        1.563028e-06            GWh/person      18.509311   GWh commercial mechanical energy
# 52        Commercial         Commercial           Commercial   Other Appliances        EL Appliances  1159.315317          NaN          NaN          NaN        NaN          NaN          NaN          NaN    1.000000        9.789898e-05            GWh/person    1159.315317                    GWh electricity
# 53        Industrial  Large enterprises               Cement       Process Heat            FG Boiler          NaN  1399.678678          NaN          NaN        NaN          NaN          NaN          NaN    0.918466        3.564104e-04        GWh/ton cement    1285.557869                      GWh high_temp
# 54        Industrial  Large enterprises               Cement       Process Heat            EL Boiler     0.000000          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.950000        5.000000e-04        GWh/ton cement       0.000000                      GWh high_temp
# 55        Industrial  Large enterprises               Cement          Machinery     EL Ind Machinery   432.812036          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.900000        1.079942e-04        GWh/ton cement     389.530832   GWh industrial mechanical energy
# 56        Industrial  Large enterprises         Pulp & Paper       Process Heat            FG Boiler          NaN   248.365920          NaN          NaN        NaN          NaN          NaN          NaN    0.918466        1.140579e+01          GWh/industry     228.115758                      GWh high_temp
# 57        Industrial  Large enterprises         Pulp & Paper       Process Heat            EL Boiler     0.000000          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.950000        5.000000e-04        GWh/ton cement       0.000000                      GWh high_temp
# 58        Industrial  Large enterprises         Pulp & Paper          Machinery     EL Ind Machinery     1.794960          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.900000        8.077320e-02          GWh/industry       1.615464   GWh industrial mechanical energy
# 59        Industrial  Large enterprises  Ceramic & Porcelain       Process Heat            FG Boiler          NaN  2164.140432          NaN          NaN        NaN          NaN          NaN          NaN    0.918466        8.316696e+00          GWh/industry    1987.690322                      GWh high_temp
# 60        Industrial  Large enterprises  Ceramic & Porcelain       Process Heat            EL Boiler     0.000000          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.950000        5.000000e-04        GWh/ton cement       0.000000                      GWh high_temp
# 61        Industrial  Large enterprises  Ceramic & Porcelain          Machinery     EL Ind Machinery    21.449772          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.900000        8.077320e-02          GWh/industry      19.304795   GWh industrial mechanical energy
# 62        Industrial  Large enterprises    Foods & Beverages       Process Heat            FG Boiler          NaN  1488.562663          NaN          NaN        NaN          NaN          NaN          NaN    0.918466        6.835974e+00          GWh/industry    1367.194825                      GWh high_temp
# 63        Industrial  Large enterprises    Foods & Beverages       Process Heat            EL Boiler     0.000000          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.950000        5.000000e-04        GWh/ton cement       0.000000                      GWh high_temp
# 64        Industrial  Large enterprises    Foods & Beverages          Machinery     EL Ind Machinery    17.949600          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.900000        8.077320e-02          GWh/industry      16.154640   GWh industrial mechanical energy
# 65        Industrial  Large enterprises            Chemicals       Process Heat            FG Boiler          NaN   155.486483          NaN          NaN        NaN          NaN          NaN          NaN    0.918466        6.491323e+00          GWh/industry     142.809114                      GWh high_temp
# 66        Industrial  Large enterprises            Chemicals       Process Heat            EL Boiler     0.000000          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.950000        5.000000e-04        GWh/ton cement       0.000000                      GWh high_temp
# 67        Industrial  Large enterprises            Chemicals          Machinery     EL Ind Machinery     1.974456          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.900000        8.077320e-02          GWh/industry       1.777010   GWh industrial mechanical energy
# 68        Industrial  Large enterprises         Construction       Process Heat            FG Boiler          NaN   192.705785          NaN          NaN        NaN          NaN          NaN          NaN    0.918466        4.538302e+00          GWh/industry     176.993793                      GWh high_temp
# 69        Industrial  Large enterprises         Construction       Process Heat            EL Boiler     0.000000          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.950000        5.000000e-04        GWh/ton cement       0.000000                      GWh high_temp
# 70        Industrial  Large enterprises         Construction          Machinery     EL Ind Machinery     3.500172          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.900000        8.077320e-02          GWh/industry       3.150155   GWh industrial mechanical energy
# 71        Industrial  Large enterprises    Large enterprises           Lighting    Conventional_bulb   203.155535          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.102500        4.004508e-02          GWh/industry      20.823442                       GWh lighting
# 72        Industrial  Large enterprises    Large enterprises           Lighting             LED_bulb    16.490486          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.340000        1.078224e-02          GWh/industry       5.606765                       GWh lighting
# 73        Industrial              MSMEs                MSMEs       Process Heat            FG Boiler          NaN  3068.046652          NaN          NaN        NaN          NaN          NaN          NaN    0.918466        2.379588e-04            GWh/person    2817.897834                      GWh high_temp
# 74        Industrial              MSMEs                MSMEs       Process Heat            WD Boiler          NaN          NaN          NaN  5722.911036        NaN          NaN          NaN          NaN    0.856298        4.138269e-04            GWh/person    4900.519803                      GWh high_temp
# 75        Industrial              MSMEs                MSMEs       Process Heat           LPG Boiler          NaN          NaN   229.044043          NaN        NaN          NaN          NaN          NaN    0.641331        1.240446e-05            GWh/person     146.893004                      GWh high_temp
# 76        Industrial              MSMEs                MSMEs       Process Heat           LFO Boiler          NaN          NaN          NaN          NaN        NaN          NaN          NaN    14.963438    0.864293        1.092116e-06            GWh/person      12.932792                      GWh high_temp
# 77        Industrial              MSMEs                MSMEs       Process Heat            DS Boiler          NaN          NaN          NaN          NaN        NaN   333.757175          NaN          NaN    0.376393        1.060836e-05            GWh/person     125.623749                      GWh high_temp
# 78        Industrial              MSMEs                MSMEs       Process Heat            EL Boiler     0.000000          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.950000        5.000000e-04        GWh/ton cement       0.000000                      GWh high_temp
# 79        Industrial              MSMEs                MSMEs          Machinery     EL Ind Machinery  1277.687167          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.900000        9.710546e-05            GWh/person    1149.918450   GWh industrial mechanical energy
# 80       Agriculture        Agriculture          Agriculture   Tractor & Others           DS Tractor          NaN          NaN          NaN          NaN        NaN    34.028994          NaN          NaN    0.678960        1.246907e-05           GWh/hectare      50.119291      GWh tractor mechanical energy
# 81       Agriculture        Agriculture          Agriculture         Irrigation     DS Agr Machinery          NaN          NaN          NaN          NaN        NaN   341.314908          NaN          NaN    0.376393        3.196138e-05           GWh/hectare     128.468424  GWh agriculture mechanical energy
# 82       Agriculture        Agriculture          Agriculture         Irrigation     EL Agr Machinery   111.661404          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.900000        2.500200e-05           GWh/hectare     100.495264  GWh agriculture mechanical energy
# 83            Mining           Zinc Ore             Zinc Ore          Machinery     DS Min Machinery          NaN          NaN          NaN          NaN        NaN  1457.049520          NaN          NaN    0.376393        1.097863e-03               GWh/ton     548.422734       GWh mining mechanical energy
# 84            Mining           Zinc Ore             Zinc Ore          Machinery     EL Min Machinery   539.731162          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.900000        9.724176e-04               GWh/ton     485.758046       GWh mining mechanical energy
# 85            Mining           Lead Ore             Lead Ore          Machinery     DS Min Machinery          NaN          NaN          NaN          NaN        NaN   391.028288          NaN          NaN    0.376393        1.578401e-03               GWh/ton     147.180175       GWh mining mechanical energy
# 86            Mining           Lead Ore             Lead Ore          Machinery     EL Min Machinery   105.073751          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.900000        1.014156e-03               GWh/ton      94.566376       GWh mining mechanical energy
# 87            Mining            Tin Ore              Tin Ore          Machinery     DS Min Machinery          NaN          NaN          NaN          NaN        NaN   552.112052          NaN          NaN    0.376393        1.056557e-02               GWh/ton     207.810920       GWh mining mechanical energy
# 88            Mining            Tin Ore              Tin Ore          Machinery     EL Min Machinery    47.179287          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.900000        2.158830e-03               GWh/ton      42.461358       GWh mining mechanical energy
# 89            Mining         Copper Ore           Copper Ore          Machinery     DS Min Machinery          NaN          NaN          NaN          NaN        NaN    35.575092          NaN          NaN    0.376393        4.045489e-03               GWh/ton      13.390203       GWh mining mechanical energy
# 90            Mining         Copper Ore           Copper Ore          Machinery     EL Min Machinery    10.826054          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.900000        2.943720e-03               GWh/ton       9.743448       GWh mining mechanical energy
# 91  Fishing & Others   Fishing & Others     Fishing & Others          Machinery    DS Fish Machinery          NaN          NaN          NaN          NaN        NaN   507.356780          NaN          NaN    0.376393        1.612617e-05            GWh/person     190.965364      GWh fishing mechanical energy
# 92  Fishing & Others   Fishing & Others     Fishing & Others          Machinery    EL Fish Machinery   287.328800          NaN          NaN          NaN        NaN          NaN          NaN          NaN    0.900000        2.183727e-05            GWh/person     258.595920      GWh fishing mechanical energy

# %%
list_sector = df_EUD['Sector'].unique().tolist()
list_subsector = df_EUD['Subsector'].unique().tolist()
list_class = df_EUD['Class'].unique().tolist()
list_usage = df_EUD['Type of usage'].unique().tolist()
list_technology = df_EUD['Technology'].unique().tolist()
list_usage
# Out:
# ['Water Heating',
#  'Cooking',
#  'Food Preservation',
#  'Space Heating',
#  'Space Cooling',
#  'Lighting',
#  'Other Appliances',
#  'Road',
#  'Rail',
#  'Water',
#  'Air',
#  'Water heating',
#  'Machinery',
#  'Process Heat',
#  'Tractor & Others',
#  'Irrigation']

# %%
# Group by 'Usage' and aggregate 'End_Use_Demand' by sum
agg_df = df_EUD.groupby(['Sector', 'Subsector', 'Class', 'Type of usage', 'EUD units']).agg({'EUD': 'sum'}).reset_index()

agg_df
# Out:
#               Sector          Subsector                Class  \
# 0        Agriculture        Agriculture          Agriculture
# 1        Agriculture        Agriculture          Agriculture
# 2         Commercial         Commercial           Commercial
# 3         Commercial         Commercial           Commercial
# 4         Commercial         Commercial           Commercial
# 5         Commercial         Commercial           Commercial
# 6         Commercial         Commercial           Commercial
# 7   Fishing & Others   Fishing & Others     Fishing & Others
# 8         Industrial  Large enterprises               Cement
# 9         Industrial  Large enterprises               Cement
# 10        Industrial  Large enterprises  Ceramic & Porcelain
# 11        Industrial  Large enterprises  Ceramic & Porcelain
# 12        Industrial  Large enterprises            Chemicals
# 13        Industrial  Large enterprises            Chemicals
# 14        Industrial  Large enterprises         Construction
# 15        Industrial  Large enterprises         Construction
# 16        Industrial  Large enterprises    Foods & Beverages
# 17        Industrial  Large enterprises    Foods & Beverages
# 18        Industrial  Large enterprises    Large enterprises
# 19        Industrial  Large enterprises         Pulp & Paper
# 20        Industrial  Large enterprises         Pulp & Paper
# 21        Industrial              MSMEs                MSMEs
# 22        Industrial              MSMEs                MSMEs
# 23            Mining         Copper Ore           Copper Ore
# 24            Mining           Lead Ore             Lead Ore
# 25            Mining            Tin Ore              Tin Ore
# 26            Mining           Zinc Ore             Zinc Ore
# 27   Public Lighting    Public Lighting      Public Lighting
# 28       Residential        Residential          Residential
# 29       Residential        Residential          Residential
# 30       Residential        Residential          Residential
# 31       Residential        Residential          Residential
# 32       Residential        Residential          Residential
# 33       Residential        Residential          Residential
# 34       Residential        Residential          Residential
# 35         Transport            Freight              Freight
# 36         Transport            Freight              Freight
# 37         Transport            Freight              Freight
# 38         Transport            Freight              Freight
# 39         Transport         Passengers           Passengers
# 40         Transport         Passengers           Passengers
#
#         Type of usage                          EUD units            EUD
# 0          Irrigation  GWh agriculture mechanical energy     228.963688
# 1    Tractor & Others      GWh tractor mechanical energy      50.119291
# 2             Cooking                        GWh cooking     304.174174
# 3            Lighting                       GWh lighting      30.135947
# 4           Machinery   GWh commercial mechanical energy      77.001946
# 5    Other Appliances                    GWh electricity    1159.315317
# 6       Water heating                       GWh low_temp     137.413423
# 7           Machinery      GWh fishing mechanical energy     449.561284
# 8           Machinery   GWh industrial mechanical energy     389.530832
# 9        Process Heat                      GWh high_temp    1285.557869
# 10          Machinery   GWh industrial mechanical energy      19.304795
# 11       Process Heat                      GWh high_temp    1987.690322
# 12          Machinery   GWh industrial mechanical energy       1.777010
# 13       Process Heat                      GWh high_temp     142.809114
# 14          Machinery   GWh industrial mechanical energy       3.150155
# 15       Process Heat                      GWh high_temp     176.993793
# 16          Machinery   GWh industrial mechanical energy      16.154640
# 17       Process Heat                      GWh high_temp    1367.194825
# 18           Lighting                       GWh lighting      26.430207
# 19          Machinery   GWh industrial mechanical energy       1.615464
# 20       Process Heat                      GWh high_temp     228.115758
# 21          Machinery   GWh industrial mechanical energy    1149.918450
# 22       Process Heat                      GWh high_temp    8003.867183
# 23          Machinery       GWh mining mechanical energy      23.133652
# 24          Machinery       GWh mining mechanical energy     241.746550
# 25          Machinery       GWh mining mechanical energy     250.272278
# 26          Machinery       GWh mining mechanical energy    1034.180780
# 27           Lighting                GWh public lighting      54.132812
# 28            Cooking                        GWh cooking    4743.548273
# 29  Food Preservation              GWh food preservation     341.880450
# 30           Lighting                       GWh lighting      48.132368
# 31   Other Appliances                    GWh electricity     819.071520
# 32      Space Cooling                  GWh space cooling      97.934156
# 33      Space Heating                  GWh space heating      21.246432
# 34      Water Heating                       GWh low_temp    1166.639294
# 35                Air                            Mkm-ton    2133.412513
# 36               Rail                            Mkm-ton     803.182891
# 37               Road                            Mkm-ton   12251.111364
# 38              Water                            Mkm-ton      54.985714
# 39               Rail                      Mkm-passenger     353.159354
# 40               Road                      Mkm-passenger  345147.035862

# %%
agg_df['EUD'].sum()
# Out:
# 386821.6017515183

# %%
# Group by 'Usage' and aggregate 'End_Use_Demand' by sum
agg_df_2 = df_EUD.groupby(['Technology', 'Efficiency' ,'EUD units']).agg({'EUD': 'sum'}).reset_index()

# Especifica el nombre del archivo Excel que deseas crear
nombre_archivo_excel = "datos_agregados.xlsx"
agg_df_2.to_excel(nombre_archivo_excel, index=False, engine='openpyxl')

# Para descargar el archivo en Google Colab, utiliza el siguiente código
from google.colab import files
files.download(nombre_archivo_excel)

agg_df_2
# Out:
#              Technology  Efficiency                          EUD units  \
# 0     Conventional_bulb    0.102500                       GWh lighting
# 1    Conventional_light    0.102500                GWh public lighting
# 2      DS Agr Machinery    0.376393  GWh agriculture mechanical energy
# 3               DS Boat    0.117408                            Mkm-ton
# 4             DS Boiler    0.376393                      GWh high_temp
# 5                DS Bus    0.115784                      Mkm-passenger
# 6                DS Car    0.718476                      Mkm-passenger
# 7   DS Cargo motorcycle    6.848640                            Mkm-ton
# 8     DS Comm Machinery    0.376393   GWh commercial mechanical energy
# 9     DS Fish Machinery    0.376393      GWh fishing mechanical energy
# 10     DS Min Machinery    0.376393       GWh mining mechanical energy
# 11        DS Motorcycle    0.678960                      Mkm-passenger
# 12      DS Pickup truck    2.030476                      Mkm-passenger
# 13               DS SUV    1.858667                      Mkm-passenger
# 14           DS Tractor    0.678960      GWh tractor mechanical energy
# 15             DS Train    0.073195                            Mkm-ton
# 16             DS Truck    0.678960                            Mkm-ton
# 17               DS Van    3.397744                            Mkm-ton
# 18                EL AC    0.314300                  GWh space cooling
# 19     EL Agr Machinery    0.900000  GWh agriculture mechanical energy
# 20        EL Appliances    1.000000                    GWh electricity
# 21            EL Boiler    0.950000                      GWh high_temp
# 22               EL Car    0.160998                      Mkm-passenger
# 23    EL Comm Machinery    0.825000   GWh commercial mechanical energy
# 24    EL Fish Machinery    0.900000      GWh fishing mechanical energy
# 25            EL Heater    1.000000                  GWh space heating
# 26     EL Ind Machinery    0.900000   GWh industrial mechanical energy
# 27     EL Min Machinery    0.900000       GWh mining mechanical energy
# 28      EL Refrigerator    0.358127              GWh food preservation
# 29            EL Shower    1.000000                       GWh low_temp
# 30             EL Stove    1.000000                        GWh cooking
# 31           EL Tramway    0.070382                      Mkm-passenger
# 32        EL appliances    1.000000                    GWh electricity
# 33            FG Boiler    0.891518                       GWh low_temp
# 34            FG Boiler    0.918466                      GWh high_temp
# 35               FG Bus    0.174988                      Mkm-passenger
# 36               FG Car    0.617935                      Mkm-passenger
# 37        FG Motorcycle    0.206446                      Mkm-passenger
# 38      FG Pickup truck    2.340662                      Mkm-passenger
# 39               FG SUV    0.969034                      Mkm-passenger
# 40             FG Stove    0.475000                        GWh cooking
# 41             FG Truck    0.524964                            Mkm-ton
# 42               FG Van    4.033141                            Mkm-ton
# 43               GS Bus    0.035941                      Mkm-passenger
# 44               GS Car    0.308069                      Mkm-passenger
# 45  GS Cargo motorcycle    0.776334                            Mkm-ton
# 46        GS Motorcycle    0.388167                      Mkm-passenger
# 47      GS Pickup truck    0.677752                      Mkm-passenger
# 48               GS SUV    0.506602                      Mkm-passenger
# 49             GS Truck    0.208748                            Mkm-ton
# 50               GS Van    2.260928                            Mkm-ton
# 51             LED_bulb    0.340000                       GWh lighting
# 52           LFO Boiler    0.864293                      GWh high_temp
# 53            LFO Stove    0.494000                        GWh cooking
# 54         LFO aircraft    0.480000                            Mkm-ton
# 55           LPG Boiler    0.641331                      GWh high_temp
# 56            LPG Stove    0.641331                        GWh cooking
# 57        Solar Thermal    1.000000                       GWh low_temp
# 58            WD Boiler    0.856298                      GWh high_temp
# 59             WD Stove    0.160000                        GWh cooking
#
#               EUD
# 0       82.488328
# 1       54.132812
# 2      128.468424
# 3       54.985714
# 4      125.623749
# 5    68884.024735
# 6     4874.192322
# 7        0.018688
# 8       58.492635
# 9      190.965364
# 10     916.804032
# 11    1049.686010
# 12     353.602661
# 13    1250.171219
# 14      50.119291
# 15     803.182891
# 16    2690.559053
# 17      22.755748
# 18      97.934156
# 19     100.495264
# 20    1159.315317
# 21       0.000000
# 22     136.388864
# 23      18.509311
# 24     258.595920
# 25      21.246432
# 26    1581.451346
# 27     632.529228
# 28     341.880450
# 29    1156.543310
# 30      58.859962
# 31     353.159354
# 32     819.071520
# 33     135.749378
# 34    8006.259515
# 35   24657.521093
# 36    1744.751420
# 37     375.742490
# 38     126.574559
# 39     447.507580
# 40    1124.528128
# 41     963.104535
# 42       8.145580
# 43  217480.576591
# 44   15388.795306
# 45       0.052881
# 46    3314.067662
# 47    1116.393980
# 48    3947.039370
# 49    8494.630453
# 50      71.844426
# 51      22.210194
# 52      12.932792
# 53      17.247856
# 54    2133.412513
# 55     146.893004
# 56    3721.651454
# 57      11.760030
# 58    4900.519803
# 59     125.435048

# %%
def projected_EUD(EUD_DF_per_use, df_population, df_industry, df_mining, target_year):
    projected_df = EUD_DF_per_use.copy()  # Hacer una copia del DataFrame original
    # Definir los sectores directamente en listas para la comprobación
    sectors_population_based = ['Residential', 'Commercial', 'Public Lighting', 'Transport', 'Agriculture', 'Fishing & Others']

    # Iterar sobre cada fila del DataFrame
    for i, row in projected_df.iterrows():
        sector = row['Sector']
        subsector = row['Subsector']  # Usar 'Subsector' para la comprobación en el sector de minería
        current_value = row['EUD']

        # Comprobación para sectores basados en población
        if sector in sectors_population_based:
            current_projection = df_population[df_population['Year'] == 2021]['Population'].values[0]
            target_projection = df_population[df_population['Year'] == target_year]['Population'].values[0]
            projected_value = (current_value / current_projection) * target_projection
            projected_df.at[i, 'EUD'] = projected_value

        # Comprobación para el sector industrial
        elif sector == 'Industrial':
            current_projection = df_industry[df_industry['Year'] == 2021]['Volume of Sales Index'].values[0]
            target_projection = df_industry[df_industry['Year'] == target_year]['Volume of Sales Index'].values[0]
            projected_value = (current_value / current_projection) * target_projection
            projected_df.at[i, 'EUD'] = projected_value

        # Comprobación para el sector minero
        elif sector == 'Mining':
            # Lista de metales a comprobar
            metals = ['Tin Ore', 'Copper Ore', 'Lead Ore', 'Zinc Ore']
            # Verificar si el subsector corresponde a alguno de los metales
            if subsector in metals:
                metal = subsector  # El 'metal' específico se identifica directamente por el 'subsector'
                current_projection = df_mining[df_mining['Year'] == 2021][metal].values[0]
                target_projection = df_mining[df_mining['Year'] == target_year][metal].values[0]
                projected_value = (current_value / current_projection) * target_projection
                projected_df.at[i, 'EUD'] = projected_value

        # Si no se encuentra coincidencia, se deja el valor sin cambios

    return projected_df

# %%
# Estimate the total EUD per type of usage for a given year
projected_df = projected_EUD(agg_df, df_population, df_industry, df_mining, 2050)
projected_df
# Out:
#               Sector          Subsector                Class  \
# 0        Agriculture        Agriculture          Agriculture
# 1        Agriculture        Agriculture          Agriculture
# 2         Commercial         Commercial           Commercial
# 3         Commercial         Commercial           Commercial
# 4         Commercial         Commercial           Commercial
# 5         Commercial         Commercial           Commercial
# 6         Commercial         Commercial           Commercial
# 7   Fishing & Others   Fishing & Others     Fishing & Others
# 8         Industrial  Large enterprises               Cement
# 9         Industrial  Large enterprises               Cement
# 10        Industrial  Large enterprises  Ceramic & Porcelain
# 11        Industrial  Large enterprises  Ceramic & Porcelain
# 12        Industrial  Large enterprises            Chemicals
# 13        Industrial  Large enterprises            Chemicals
# 14        Industrial  Large enterprises         Construction
# 15        Industrial  Large enterprises         Construction
# 16        Industrial  Large enterprises    Foods & Beverages
# 17        Industrial  Large enterprises    Foods & Beverages
# 18        Industrial  Large enterprises    Large enterprises
# 19        Industrial  Large enterprises         Pulp & Paper
# 20        Industrial  Large enterprises         Pulp & Paper
# 21        Industrial              MSMEs                MSMEs
# 22        Industrial              MSMEs                MSMEs
# 23            Mining         Copper Ore           Copper Ore
# 24            Mining           Lead Ore             Lead Ore
# 25            Mining            Tin Ore              Tin Ore
# 26            Mining           Zinc Ore             Zinc Ore
# 27   Public Lighting    Public Lighting      Public Lighting
# 28       Residential        Residential          Residential
# 29       Residential        Residential          Residential
# 30       Residential        Residential          Residential
# 31       Residential        Residential          Residential
# 32       Residential        Residential          Residential
# 33       Residential        Residential          Residential
# 34       Residential        Residential          Residential
# 35         Transport            Freight              Freight
# 36         Transport            Freight              Freight
# 37         Transport            Freight              Freight
# 38         Transport            Freight              Freight
# 39         Transport         Passengers           Passengers
# 40         Transport         Passengers           Passengers
#
#         Type of usage                          EUD units            EUD
# 0          Irrigation  GWh agriculture mechanical energy     309.552812
# 1    Tractor & Others      GWh tractor mechanical energy      67.759948
# 2             Cooking                        GWh cooking     411.235388
# 3            Lighting                       GWh lighting      40.742998
# 4           Machinery   GWh commercial mechanical energy     104.104582
# 5    Other Appliances                    GWh electricity    1567.363455
# 6       Water heating                       GWh low_temp     185.779291
# 7           Machinery      GWh fishing mechanical energy     607.794892
# 8           Machinery   GWh industrial mechanical energy     639.378971
# 9        Process Heat                      GWh high_temp    2110.124796
# 10          Machinery   GWh industrial mechanical energy      31.687042
# 11       Process Heat                      GWh high_temp    3262.610526
# 12          Machinery   GWh industrial mechanical energy       2.916799
# 13       Process Heat                      GWh high_temp     234.408003
# 14          Machinery   GWh industrial mechanical energy       5.170689
# 15       Process Heat                      GWh high_temp     290.519005
# 16          Machinery   GWh industrial mechanical energy      26.516353
# 17       Process Heat                      GWh high_temp    2244.124338
# 18           Lighting                       GWh lighting      43.382750
# 19          Machinery   GWh industrial mechanical energy       2.651635
# 20       Process Heat                      GWh high_temp     374.430999
# 21          Machinery   GWh industrial mechanical energy    1887.485187
# 22       Process Heat                      GWh high_temp   13137.610541
# 23          Machinery       GWh mining mechanical energy      50.550648
# 24          Machinery       GWh mining mechanical energy     506.551520
# 25          Machinery       GWh mining mechanical energy     217.465169
# 26          Machinery       GWh mining mechanical energy    1974.529505
# 27           Lighting                GWh public lighting      73.186122
# 28            Cooking                        GWh cooking    6413.151020
# 29  Food Preservation              GWh food preservation     462.213270
# 30           Lighting                       GWh lighting      65.073680
# 31   Other Appliances                    GWh electricity    1107.362896
# 32      Space Cooling                  GWh space cooling     132.404373
# 33      Space Heating                  GWh space heating      28.724611
# 34      Water Heating                       GWh low_temp    1577.265277
# 35                Air                            Mkm-ton    2884.316939
# 36               Rail                            Mkm-ton    1085.881892
# 37               Road                            Mkm-ton   16563.176515
# 38              Water                            Mkm-ton      74.339222
# 39               Rail                      Mkm-passenger     477.462048
# 40               Road                      Mkm-passenger  466629.606794

# %%
# Group by 'Usage' and aggregate 'End_Use_Demand' by sum
projected_df = projected_df.groupby(['Sector', 'EUD units']).agg({'EUD': 'sum'}).reset_index()

projected_df
# Out:
#               Sector                          EUD units            EUD
# 0        Agriculture  GWh agriculture mechanical energy     309.552812
# 1        Agriculture      GWh tractor mechanical energy      67.759948
# 2         Commercial   GWh commercial mechanical energy     104.104582
# 3         Commercial                        GWh cooking     411.235388
# 4         Commercial                    GWh electricity    1567.363455
# 5         Commercial                       GWh lighting      40.742998
# 6         Commercial                       GWh low_temp     185.779291
# 7   Fishing & Others      GWh fishing mechanical energy     607.794892
# 8         Industrial                      GWh high_temp   21653.828209
# 9         Industrial   GWh industrial mechanical energy    2595.806677
# 10        Industrial                       GWh lighting      43.382750
# 11            Mining       GWh mining mechanical energy    2749.096840
# 12   Public Lighting                GWh public lighting      73.186122
# 13       Residential                        GWh cooking    6413.151020
# 14       Residential                    GWh electricity    1107.362896
# 15       Residential              GWh food preservation     462.213270
# 16       Residential                       GWh lighting      65.073680
# 17       Residential                       GWh low_temp    1577.265277
# 18       Residential                  GWh space cooling     132.404373
# 19       Residential                  GWh space heating      28.724611
# 20         Transport                      Mkm-passenger  467107.068842
# 21         Transport                            Mkm-ton   20607.714569
